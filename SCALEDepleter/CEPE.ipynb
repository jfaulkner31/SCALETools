# %%
##################################################################
########################### USER INPUT ###########################
##################################################################
"""
  Step 0 - ask yourself:
  Is first step length ok in the input file?
  Is the FMA parameter set to yes?
  Are the NPG and other neutron parameters correct?
  Is addnux set to 0 in the triton base file?

  To run via python command line: python ...py machinefile tmpdir numProcsTransport
"""

# fissionable regions - used for origen later
fissionable_mats = [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116] # list of fissionable materials we are depleting -
fissionable_mats_vols = [6.02834870915574000000E+04]*16 # list of vols for each fissionable material
residual_number_density = 1e-20 # residual number density for trace nuclides in initial conditions

# ORIGEN information
include_non_fission_material_power = True # include power effects from non-fissionable materials?
print_transport_powers = True  # print powers after every transport step?
system_IHM_mass_grams = 7.213356e+04 # heavy metal mass in grams i the initial system - the ENTIRE system.
specific_power = [200, 200, 200, 200, 200, 200] # MW/TIHM
steplength_days = [5, 5, 5, 5, 5, 5] # length of each step in days
origen_predictor_divs = 100 # number of time divs for predictor - use for CEBM model only
origen_LI_divs = 10 # how many times during origen calculation the f33 is divided - value of 10 means we use 10 interpolated f33 files per material - use for CELI scheme
origen_steps_per_div = 10 # how many origen substeps are used for each division of f33 files

# File Handles - keep as is - only consider changing the addnux dictionary
addnuxdictbase = 'addnuxDicts/addnux2Dict.dict'
base_triton = 'triton_base.inp'
origen_base = 'baseOrigenFile.inp'
origenResults_F71dir = 'OrigenResults_F71dir'
MonteCarloResults_F33dir = 'MonteCarloResults_F33'

# whether we want to print xenon and power substepping information - reccomended yes
print_substepping = True

##################################################################
########################### EXECUTION ############################
##################################################################

# command line args
import sys
# machinefile = sys.argv[1]
# tmpdir = sys.argv[2]
# Nprocs = int(sys.argv[3])
machinefile = 'asdasdasd'
tmpdir = 'tmp'
Nprocs = 1


if Nprocs <= 0:
  raise Exception("Nprocs for transport cannot be less than or equal to zero!")
elif Nprocs == 1:
  is_parallel = False
else:
  is_parallel = True

import CEPE
CEPE.CEPE(fissionable_mats=fissionable_mats,
          fissionable_mats_vols=fissionable_mats_vols,
          residual_number_density=residual_number_density,
          include_non_fission_material_power=include_non_fission_material_power,
          print_transport_powers=print_transport_powers,
          system_IHM_mass_grams=system_IHM_mass_grams,
          specific_power=specific_power,
          steplength_days=steplength_days,
          origen_predictor_divs=origen_predictor_divs,
          addnuxdictbase=addnuxdictbase,
          base_triton=base_triton,
          origen_base=origen_base,
          origenResults_F71dir=origenResults_F71dir,
          MonteCarloResults_F33dir=MonteCarloResults_F33dir,
          Nprocs=Nprocs,
          machinefile=machinefile,
          tmpdir=tmpdir,
          is_parallel=is_parallel,
          origen_LI_divs=origen_LI_divs,
          origen_steps_per_div=origen_steps_per_div,
          print_substepping=print_substepping)
# Out:
# NPROCS 1
# MACHINEFILE asdasdasd
# BASE_TRITON triton_base.inp
# read comp found! Now starting comp directory.
# end comp found! Now finalizing comp directory.
# Not removing directory tmp_blender since it does not exist
# Not removing directory tmp_origen_CORRECTOR_step1 since it does not exist
# Not removing directory tmp_origen_PREDICTOR_step2 since it does not exist
# Not removing directory tmp_origen_CORRECTOR_step2 since it does not exist
# Not removing directory tmp_origen_PREDICTOR_step3 since it does not exist
# Not removing directory tmp_origen_CORRECTOR_step3 since it does not exist
# Not removing directory tmp_origen_PREDICTOR_step4 since it does not exist
# Not removing directory tmp_origen_CORRECTOR_step4 since it does not exist
# Not removing directory tmp_origen_PREDICTOR_step5 since it does not exist
# Not removing directory tmp_origen_CORRECTOR_step5 since it does not exist
# read comp found! Now starting comp directory.
# end comp found! Now finalizing comp directory.
# read comp found! Now starting comp directory.
# end comp found! Now finalizing comp directory.
# Now making standard comp file for material 101  | output= StdCmpMix101_corrected_cmp
# Now making standard comp file for material 102  | output= StdCmpMix102_corrected_cmp
# Now making standard comp file for material 103  | output= StdCmpMix103_corrected_cmp
# Now making standard comp file for material 104  | output= StdCmpMix104_corrected_cmp
# Now making standard comp file for material 105  | output= StdCmpMix105_corrected_cmp
# Now making standard comp file for material 106  | output= StdCmpMix106_corrected_cmp
# Now making standard comp file for material 107  | output= StdCmpMix107_corrected_cmp
# Now making standard comp file for material 108  | output= StdCmpMix108_corrected_cmp
# Now making standard comp file for material 109  | output= StdCmpMix109_corrected_cmp
# Now making standard comp file for material 110  | output= StdCmpMix110_corrected_cmp
# Now making standard comp file for material 111  | output= StdCmpMix111_corrected_cmp
# Now making standard comp file for material 112  | output= StdCmpMix112_corrected_cmp
# Now making standard comp file for material 113  | output= StdCmpMix113_corrected_cmp
# Now making standard comp file for material 114  | output= StdCmpMix114_corrected_cmp
# Now making standard comp file for material 115  | output= StdCmpMix115_corrected_cmp
# Now making standard comp file for material 116  | output= StdCmpMix116_corrected_cmp
# Started process with PID: 1617991
# Now sleeping python for 5 seconds
#  *******************************************************************************
#  *                                                                             *
#  *                                 SCALE 6.3.1                                 *
#  *                                -------------                                *
#  *                                   2023-02                                   *
#  *                                                                             *
#  *           SCALE:  A Comprehensive Modeling and Simulation Suite             *
#  *                   for Nuclear Safety Analysis and Design                    *
#  *                                                                             *
#  *                      Reactor and Nuclear Systems Division                   *
#  *                        Oak Ridge National Laboratory                        *
#  *                                                                             *
#  *                           http://scale.ornl.gov                             *
#  *                            scalehelp@ornl.gov                               *
#  *                                                                             *
#  *******************************************************************************
#  *******************************************************************************
#
#                   Job Information
#                   ---------------
#       Job started on ME04L0332LAB04.me.gatech.edu on Sat 2024-12-07 06:13:44
#       Working directory: /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp
#       Input file name  : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/triton_base_stdcmp_corrected_cmp.inp
#       Output file name : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/triton_base_stdcmp_corrected_cmp.out
#       SCALE executable : /codes/SCALE-6.3.1/bin/scale
#
#  *******************************************************************************
#
# ***Created 18 infinite homogeneous cells from unreferenced mixtures.
# ***Warning: in multi group mode, energy group boundaries used for tallying mixture fluxes are always
#  acquired from the multi group library used by transport.
#
# >>> Loading SCALE Standard Composition Library from /codes/SCALE-6.3.1/data/scale.rev40.sclib
# >>> Loading CE library /codes/SCALE-6.3.1/data/ce_v7.1_endf.xml
# Loading      nuclide        h-1 @ 800K
# Loading      nuclide       li-6 @ 900K
# Loading      nuclide       li-6 @ 1200K
# Loading      nuclide       li-7 @ 900K
# Loading      nuclide       li-7 @ 1200K
# Loading      nuclide       be-9 @ 900K
# Loading      nuclide       be-9 @ 1200K
# Loading      nuclide       b-10 @ 900K
# Loading      nuclide       b-10 @ 1200K
# Loading      nuclide       b-11 @ 900K
# Loading      nuclide       b-11 @ 1200K
# Loading      nuclide          c @ 900K
# Loading      nuclide          c @ 1200K
# Loading      nuclide       n-14 @ 900K
# Loading      nuclide       n-14 @ 1200K
# Loading      nuclide       o-16 @ 900K
# Loading      nuclide       o-16 @ 1200K
# Loading      nuclide       f-19 @ 900K
# Loading      nuclide       f-19 @ 1200K
# Loading      nuclide      kr-83 @ 900K
# Loading      nuclide      kr-83 @ 1200K
# Loading      nuclide      zr-91 @ 900K
# Loading      nuclide      zr-91 @ 1200K
# Loading      nuclide      zr-93 @ 900K
# Loading      nuclide      zr-93 @ 1200K
# Loading      nuclide      zr-94 @ 900K
# Loading      nuclide      zr-94 @ 1200K
# Loading      nuclide      zr-95 @ 900K
# Loading      nuclide      zr-95 @ 1200K
# Loading      nuclide      zr-96 @ 900K
# Loading      nuclide      zr-96 @ 1200K
# Loading      nuclide      nb-93 @ 900K
# Loading      nuclide      nb-93 @ 1200K
# Loading      nuclide      nb-95 @ 900K
# Loading      nuclide      nb-95 @ 1200K
# Loading      nuclide      mo-95 @ 900K
# Loading      nuclide      mo-95 @ 1200K
# Loading      nuclide      mo-97 @ 900K
# Loading      nuclide      mo-97 @ 1200K
# Loading      nuclide      mo-98 @ 900K
# Loading      nuclide      mo-98 @ 1200K
# Loading      nuclide      mo-99 @ 900K
# Loading      nuclide      mo-99 @ 1200K
# Loading      nuclide     mo-100 @ 900K
# Loading      nuclide     mo-100 @ 1200K
# Loading      nuclide      tc-99 @ 900K
# Loading      nuclide      tc-99 @ 1200K
# Loading      nuclide     ru-101 @ 900K
# Loading      nuclide     ru-101 @ 1200K
# Loading      nuclide     ru-102 @ 900K
# Loading      nuclide     ru-102 @ 1200K
# Loading      nuclide     ru-103 @ 900K
# Loading      nuclide     ru-103 @ 1200K
# Loading      nuclide     ru-104 @ 900K
# Loading      nuclide     ru-104 @ 1200K
# Loading      nuclide     ru-106 @ 900K
# Loading      nuclide     ru-106 @ 1200K
# Loading      nuclide     rh-103 @ 900K
# Loading      nuclide     rh-103 @ 1200K
# Loading      nuclide     rh-105 @ 900K
# Loading      nuclide     rh-105 @ 1200K
# Loading      nuclide     pd-105 @ 900K
# Loading      nuclide     pd-105 @ 1200K
# Loading      nuclide     pd-107 @ 900K
# Loading      nuclide     pd-107 @ 1200K
# Loading      nuclide     pd-108 @ 900K
# Loading      nuclide     pd-108 @ 1200K
# Loading      nuclide     ag-109 @ 900K
# Loading      nuclide     ag-109 @ 1200K
# Loading      nuclide     cd-113 @ 900K
# Loading      nuclide     cd-113 @ 1200K
# Loading      nuclide     in-115 @ 900K
# Loading      nuclide     in-115 @ 1200K
# Loading      nuclide     sn-126 @ 900K
# Loading      nuclide     sn-126 @ 1200K
# Loading      nuclide      i-127 @ 900K
# Loading      nuclide      i-127 @ 1200K
# Loading      nuclide      i-129 @ 900K
# Loading      nuclide      i-129 @ 1200K
# Loading      nuclide      i-135 @ 900K
# Loading      nuclide      i-135 @ 1200K
# Loading      nuclide     xe-131 @ 900K
# Loading      nuclide     xe-131 @ 1200K
# Loading      nuclide     xe-133 @ 900K
# Loading      nuclide     xe-133 @ 1200K
# Loading      nuclide     xe-135 @ 900K
# Loading      nuclide     xe-135 @ 1200K
# Loading      nuclide     cs-133 @ 900K
# Loading      nuclide     cs-133 @ 1200K
# Loading      nuclide     cs-134 @ 900K
# Loading      nuclide     cs-134 @ 1200K
# Loading      nuclide     cs-135 @ 900K
# Loading      nuclide     cs-135 @ 1200K
# Loading      nuclide     cs-137 @ 900K
# Loading      nuclide     cs-137 @ 1200K
# Loading      nuclide     ba-140 @ 900K
# Loading      nuclide     ba-140 @ 1200K
# Loading      nuclide     la-139 @ 900K
# Loading      nuclide     la-139 @ 1200K
# Loading      nuclide     ce-141 @ 900K
# Loading      nuclide     ce-141 @ 1200K
# Loading      nuclide     ce-142 @ 900K
# Loading      nuclide     ce-142 @ 1200K
# Loading      nuclide     ce-143 @ 900K
# Loading      nuclide     ce-143 @ 1200K
# Loading      nuclide     ce-144 @ 900K
# Loading      nuclide     ce-144 @ 1200K
# Loading      nuclide     pr-141 @ 900K
# Loading      nuclide     pr-141 @ 1200K
# Loading      nuclide     pr-143 @ 900K
# Loading      nuclide     pr-143 @ 1200K
# Loading      nuclide     nd-143 @ 900K
# Loading      nuclide     nd-143 @ 1200K
# Loading      nuclide     nd-144 @ 900K
# Loading      nuclide     nd-144 @ 1200K
# Loading      nuclide     nd-145 @ 900K
# Loading      nuclide     nd-145 @ 1200K
# Loading      nuclide     nd-146 @ 900K
# Loading      nuclide     nd-146 @ 1200K
# Loading      nuclide     nd-147 @ 900K
# Loading      nuclide     nd-147 @ 1200K
# Loading      nuclide     nd-148 @ 900K
# Loading      nuclide     nd-148 @ 1200K
# Loading      nuclide     pm-147 @ 900K
# Loading      nuclide     pm-147 @ 1200K
# Loading      nuclide     pm-148 @ 900K
# Loading      nuclide     pm-148 @ 1200K
# Loading      nuclide     pm-149 @ 900K
# Loading      nuclide     pm-149 @ 1200K
# Loading      nuclide     sm-147 @ 900K
# Loading      nuclide     sm-147 @ 1200K
# Loading      nuclide     sm-149 @ 900K
# Loading      nuclide     sm-149 @ 1200K
# Loading      nuclide     sm-150 @ 900K
# Loading      nuclide     sm-150 @ 1200K
# Loading      nuclide     sm-151 @ 900K
# Loading      nuclide     sm-151 @ 1200K
# Loading      nuclide     sm-152 @ 900K
# Loading      nuclide     sm-152 @ 1200K
# Loading      nuclide     sm-153 @ 900K
# Loading      nuclide     sm-153 @ 1200K
# Loading      nuclide     eu-151 @ 900K
# Loading      nuclide     eu-151 @ 1200K
# Loading      nuclide     eu-153 @ 900K
# Loading      nuclide     eu-153 @ 1200K
# Loading      nuclide     eu-154 @ 900K
# Loading      nuclide     eu-154 @ 1200K
# Loading      nuclide     eu-155 @ 900K
# Loading      nuclide     eu-155 @ 1200K
# Loading      nuclide     eu-156 @ 900K
# Loading      nuclide     eu-156 @ 1200K
# Loading      nuclide     gd-152 @ 900K
# Loading      nuclide     gd-152 @ 1200K
# Loading      nuclide     gd-154 @ 900K
# Loading      nuclide     gd-154 @ 1200K
# Loading      nuclide     gd-155 @ 900K
# Loading      nuclide     gd-155 @ 1200K
# Loading      nuclide     gd-156 @ 900K
# Loading      nuclide     gd-156 @ 1200K
# Loading      nuclide     gd-157 @ 900K
# Loading      nuclide     gd-157 @ 1200K
# Loading      nuclide     gd-158 @ 900K
# Loading      nuclide     gd-158 @ 1200K
# Loading      nuclide     gd-160 @ 900K
# Loading      nuclide     gd-160 @ 1200K
# Loading      nuclide      u-234 @ 900K
# Loading      nuclide      u-234 @ 1200K
# Loading      nuclide      u-235 @ 900K
# Loading      nuclide      u-235 @ 1200K
# Loading      nuclide      u-236 @ 900K
# Loading      nuclide      u-236 @ 1200K
# Loading      nuclide      u-238 @ 900K
# Loading      nuclide      u-238 @ 1200K
# Loading      nuclide     np-237 @ 900K
# Loading      nuclide     np-237 @ 1200K
# Loading      nuclide     pu-238 @ 900K
# Loading      nuclide     pu-238 @ 1200K
# Loading      nuclide     pu-239 @ 900K
# Loading      nuclide     pu-239 @ 1200K
# Loading      nuclide     pu-240 @ 900K
# Loading      nuclide     pu-240 @ 1200K
# Loading      nuclide     pu-241 @ 900K
# Loading      nuclide     pu-241 @ 1200K
# Loading      nuclide     pu-242 @ 900K
# Loading      nuclide     pu-242 @ 1200K
# Loading      nuclide     am-241 @ 900K
# Loading      nuclide     am-241 @ 1200K
# Loading      nuclide     am-242 @ 900K
# Loading      nuclide     am-242 @ 1200K
# Loading      nuclide     am-243 @ 900K
# Loading      nuclide     am-243 @ 1200K
# Loading      nuclide     cm-242 @ 900K
# Loading      nuclide     cm-242 @ 1200K
# Loading      nuclide     cm-243 @ 900K
# Loading      nuclide     cm-243 @ 1200K
# Loading      nuclide     cm-244 @ 900K
# Loading      nuclide     cm-244 @ 1200K
# Loading      nuclide    am-242m @ 900K
# Loading      nuclide    am-242m @ 1200K
#   Now executing kenovi
#
#  fhr_homogenized
#                generation     average      avg k-eff      generation    elapsed time
#   generation  k-effective   k-effective    deviation        entropy        minutes
#        1      1.21592E+00   1.00000E+00   0.00000E+00   3.54378E+00   7.66667E-02
#        2      1.23029E+00   1.00000E+00   0.00000E+00   3.52609E+00   8.86667E-02
#        3      1.23854E+00   1.23854E+00   0.00000E+00   3.51044E+00   1.00667E-01
#        4      1.22819E+00   1.23336E+00   5.17601E-03   3.49675E+00   1.12500E-01
#        5      1.22108E+00   1.22927E+00   5.06976E-03   3.49159E+00   1.24500E-01
#        6      1.21890E+00   1.22668E+00   4.42383E-03   3.50141E+00   1.36167E-01
#        7      1.20882E+00   1.22311E+00   4.94877E-03   3.48173E+00   1.48000E-01
#        8      1.23781E+00   1.22556E+00   4.72554E-03   3.47640E+00   1.60000E-01
#        9      1.23326E+00   1.22666E+00   4.14259E-03   3.45809E+00   1.71667E-01
#       10      1.23407E+00   1.22758E+00   3.70548E-03   3.46401E+00   1.83500E-01
#       11      1.23904E+00   1.22886E+00   3.50693E-03   3.45358E+00   1.95667E-01
#       12      1.23883E+00   1.22985E+00   3.29132E-03   3.44436E+00   2.07833E-01
#       13      1.22319E+00   1.22925E+00   3.03804E-03   3.42805E+00   2.19833E-01
#       14      1.22907E+00   1.23253E+00   1.05948E-02   3.43383E+00   2.32000E-01
#       15      1.22552E+00   1.23113E+00   7.00244E-03   3.43241E+00   2.44000E-01
#
#  fhr_homogenized
#                generation     average      avg k-eff      generation    elapsed time
#   generation  k-effective   k-effective    deviation        entropy        minutes
#       16      1.22906E+00   1.23078E+00   5.12360E-03   3.43698E+00   2.56167E-01
#       17      1.23027E+00   1.23071E+00   3.95132E-03   3.44019E+00   2.68333E-01
#       18      1.22923E+00   1.23053E+00   3.21235E-03   3.43276E+00   2.80333E-01
#       19      1.23336E+00   1.23084E+00   2.72765E-03   3.42975E+00   2.92500E-01
#       20      1.22274E+00   1.23003E+00   2.34515E-03   3.44783E+00   3.04500E-01
#
#  fhr_homogenized
#           ******      final results table      ******
#  best estimate system k-eff 1.2284 + or - 0.0015
#  Energy of average lethargy of Fission (eV) 1.71597E-01 + or -  2.31641E-04
#  k-effective satisfies the chi**2 test for normality at the 95 % level
#   Now executing kmart6
#
# ORIGEN initializing...
#     - mixture=101 with power=5.6879e+06, depleted by constant power
#     - mixture=102 with power=8.3215e+06, depleted by constant power
#     - mixture=103 with power=1.0374e+07, depleted by constant power
#     - mixture=104 with power=1.2435e+07, depleted by constant power
#     - mixture=105 with power=1.3810e+07, depleted by constant power
#     - mixture=106 with power=1.4838e+07, depleted by constant power
#     - mixture=107 with power=1.4794e+07, depleted by constant power
#     - mixture=108 with power=1.4990e+07, depleted by constant power
#     - mixture=109 with power=1.5712e+07, depleted by constant power
#     - mixture=110 with power=1.7035e+07, depleted by constant power
#     - mixture=111 with power=1.7571e+07, depleted by constant power
#     - mixture=112 with power=1.5405e+07, depleted by constant power
#     - mixture=113 with power=1.2923e+07, depleted by constant power
#     - mixture=114 with power=1.0777e+07, depleted by constant power
#     - mixture=115 with power=8.7829e+06, depleted by constant power
#     - mixture=116 with power=6.3003e+06, depleted by constant power
#
# ORIGEN executing (predictor half-step) multi-zone depletion...
#
#
#
# ORIGEN Substep Convergence Summary
#
#   Step:                         1
#   Begin-of-Step Time:           0 days
#   End-of-Step Time:             0.833333 days
#   Global Power Constraint:      INACTIVE
#   Global Mass Constraint:       INACTIVE
#
#                        COLUMN DEFINITIONS
#         - TSub   relative time point in the substep from t=0.0 to 1.0
#         - Flux   average flux of depletable mixtures
#         - Power  total power in depletable mixtures
#         - Mass   mass in depletable mixtures
#         - Iter   iteration index on end-of-substep power/mass
#         - Basis  total power/mass in basis mixtures
#         - RelChg current relative change (compared to stopping criteria)
#                  power constraint: change in flux scaling factor
#                  mass constraint: change in nuclide amounts
#         - Cvg?   whether the power/mass has met stopping criteria
#                  (RelChg <= Stopping Criteria)
#         - MixMax max relative change in mixture power or mass
#         - MixLoc mixture id of max change
#
#                  GLOBAL SUBSTEP DATA           |     |           POWER CONSTRAINT (INACTIVE)      |            MASS CONSTRAINT (INACTIVE)      |
#  TSub(-) Flux(n/cm2s)     Power(W)      Mass(g)| Iter|    Basis(W) RelChg(-) Cvg? MixMax(-) MixLoc|    Basis(g) RelChg(-) Cvg? MixMax(-) MixLoc|
#  ------- ------------ ------------ ------------| ----| ----------- --------- ---- --------- ------| ----------- --------- ---- --------- ------|
#   0.0000   2.9504e+14   1.9976e+08   2.5330e+07|    0|  1.9976e+08  0.00e+00   -   0.00e+00      0|  2.5330e+07  0.00e+00   -   0.00e+00      0|
#   0.2500   2.9502e+14   1.9976e+08   2.5330e+07|    0|  1.9976e+08  0.00e+00   -   0.00e+00      0|  2.5330e+07  0.00e+00   -   7.34e-09    111|
#   0.5000   2.9500e+14   1.9976e+08   2.5330e+07|    0|  1.9976e+08  0.00e+00   -   0.00e+00      0|  2.5330e+07  0.00e+00   -   7.15e-09    111|
#   0.7500   2.9502e+14   1.9976e+08   2.5330e+07|    0|  1.9976e+08  0.00e+00   -   0.00e+00      0|  2.5330e+07  0.00e+00   -   7.01e-09    111|
# Termination of process detected
#   1.0000   2.9507e+14   1.9976e+08   2.5330e+07|    0|  1.9976e+08  0.00e+00   -   0.00e+00      0|  2.5330e+07  0.00e+00   -   6.93e-09    111|
#
# ORIGEN multi-zone depletion global step 1 (predictor half-step) complete for 16 mixtures with 4 internal substeps and 128 kernel solves.
#
# >>> Loading CE library /codes/SCALE-6.3.1/data/ce_v7.1_endf.xml
# Loading      nuclide        h-1 @ 800K
# Loading      nuclide       li-6 @ 900K
# Loading      nuclide       li-6 @ 1200K
# Loading      nuclide       li-7 @ 900K
# Loading      nuclide       li-7 @ 1200K
# Loading      nuclide       be-9 @ 900K
# Loading      nuclide       be-9 @ 1200K
# Loading      nuclide       b-10 @ 900K
# Loading      nuclide       b-10 @ 1200K
# Loading      nuclide       b-11 @ 900K
# Loading      nuclide       b-11 @ 1200K
# Loading      nuclide          c @ 900K
# Loading      nuclide          c @ 1200K
# Loading      nuclide       n-14 @ 900K
# Loading      nuclide       n-14 @ 1200K
# Loading      nuclide       o-16 @ 900K
# Loading      nuclide       o-16 @ 1200K
# Loading      nuclide       f-19 @ 900K
# Loading      nuclide       f-19 @ 1200K
# Loading      nuclide      kr-83 @ 900K
# Loading      nuclide      kr-83 @ 1200K
# Loading      nuclide      zr-91 @ 900K
# Loading      nuclide      zr-91 @ 1200K
# Loading      nuclide      zr-93 @ 900K
# Loading      nuclide      zr-93 @ 1200K
# Loading      nuclide      zr-94 @ 900K
# Loading      nuclide      zr-94 @ 1200K
# Loading      nuclide      zr-95 @ 900K
# Loading      nuclide      zr-95 @ 1200K
# Loading      nuclide      zr-96 @ 900K
# Loading      nuclide      zr-96 @ 1200K
# Loading      nuclide      nb-93 @ 900K
# Loading      nuclide      nb-93 @ 1200K
# Loading      nuclide      nb-95 @ 900K
# Loading      nuclide      nb-95 @ 1200K
# Loading      nuclide      mo-95 @ 900K
# Loading      nuclide      mo-95 @ 1200K
# Loading      nuclide      mo-97 @ 900K
# Loading      nuclide      mo-97 @ 1200K
# Loading      nuclide      mo-98 @ 900K
# Loading      nuclide      mo-98 @ 1200K
# Loading      nuclide      mo-99 @ 900K
# Loading      nuclide      mo-99 @ 1200K
# Loading      nuclide     mo-100 @ 900K
# Loading      nuclide     mo-100 @ 1200K
# Loading      nuclide      tc-99 @ 900K
# Loading      nuclide      tc-99 @ 1200K
# Loading      nuclide     ru-101 @ 900K
# Loading      nuclide     ru-101 @ 1200K
# Loading      nuclide     ru-102 @ 900K
# Loading      nuclide     ru-102 @ 1200K
# Loading      nuclide     ru-103 @ 900K
# Loading      nuclide     ru-103 @ 1200K
# Loading      nuclide     ru-104 @ 900K
# Loading      nuclide     ru-104 @ 1200K
# Loading      nuclide     ru-106 @ 900K
# Loading      nuclide     ru-106 @ 1200K
# Loading      nuclide     rh-103 @ 900K
# Loading      nuclide     rh-103 @ 1200K
# Loading      nuclide     rh-105 @ 900K
# Loading      nuclide     rh-105 @ 1200K
# Loading      nuclide     pd-105 @ 900K
# Loading      nuclide     pd-105 @ 1200K
# Loading      nuclide     pd-107 @ 900K
# Loading      nuclide     pd-107 @ 1200K
# Loading      nuclide     pd-108 @ 900K
# Loading      nuclide     pd-108 @ 1200K
# Loading      nuclide     ag-109 @ 900K
# Loading      nuclide     ag-109 @ 1200K
# Loading      nuclide     cd-113 @ 900K
# Loading      nuclide     cd-113 @ 1200K
# Loading      nuclide     in-115 @ 900K
# Loading      nuclide     in-115 @ 1200K
# Loading      nuclide     sn-126 @ 900K
# Loading      nuclide     sn-126 @ 1200K
# Loading      nuclide      i-127 @ 900K
# Loading      nuclide      i-127 @ 1200K
# Loading      nuclide      i-129 @ 900K
# Loading      nuclide      i-129 @ 1200K
# Loading      nuclide      i-135 @ 900K
# Loading      nuclide      i-135 @ 1200K
# Loading      nuclide     xe-131 @ 900K
# Loading      nuclide     xe-131 @ 1200K
# Loading      nuclide     xe-133 @ 900K
# Loading      nuclide     xe-133 @ 1200K
# Loading      nuclide     xe-135 @ 900K
# Loading      nuclide     xe-135 @ 1200K
# Loading      nuclide     cs-133 @ 900K
# Loading      nuclide     cs-133 @ 1200K
# Loading      nuclide     cs-134 @ 900K
# Loading      nuclide     cs-134 @ 1200K
# Loading      nuclide     cs-135 @ 900K
# Loading      nuclide     cs-135 @ 1200K
# Process terminated after 83.77679944038391 seconds.
# Moved: _triton_mix0109.f33 from temporary directory as 109.f33
# Moved: _triton_mix0102.f33 from temporary directory as 102.f33
# Moved: _triton_mix0103.f33 from temporary directory as 103.f33
# Moved: _triton_mix0105.f33 from temporary directory as 105.f33
# Moved: _triton_mix0108.f33 from temporary directory as 108.f33
# Moved: _triton_mix0107.f33 from temporary directory as 107.f33
# Moved: _triton_mix0110.f33 from temporary directory as 110.f33
# Moved: _triton_mix0101.f33 from temporary directory as 101.f33
# Moved: _triton_mix0104.f33 from temporary directory as 104.f33
# Moved: _triton_mix0116.f33 from temporary directory as 116.f33
# Moved: _triton_mix0106.f33 from temporary directory as 106.f33
# Moved: _triton_mix0114.f33 from temporary directory as 114.f33
# Moved: _triton_mix0112.f33 from temporary directory as 112.f33
# Moved: _triton_mix0111.f33 from temporary directory as 111.f33
# Moved: _triton_mix0115.f33 from temporary directory as 115.f33
# Moved: _triton_mix0113.f33 from temporary directory as 113.f33
# NOW PRINTING POWERS
# 	 101 | 0.028440000000000003 | 0.41029568928000004
# 	 102 | 0.04161 | 0.6002954863200001
# 	 103 | 0.051870000000000006 | 0.7483135514400001
# 	 104 | 0.062175000000000015 | 0.8969808186000002
# 	 105 | 0.06905000000000001 | 0.9961644636000002
# 	 106 | 0.07419 | 1.07031776328
# 	 107 | 0.07397000000000002 | 1.0671438866400003
# 	 108 | 0.07495000000000002 | 1.0812820644000003
# 	 109 | 0.07855500000000001 | 1.1332903611600003
# 	 110 | 0.08517500000000001 | 1.2287951946000002
# 	 111 | 0.08785500000000002 | 1.2674587827600003
# 	 112 | 0.07702500000000001 | 1.1112174918000002
# 	 113 | 0.064615 | 0.9321819958800001
# 	 114 | 0.053880000000000004 | 0.7773112425600001
# 	 115 | 0.043915 | 0.63354905748
# 	 116 | 0.031505000000000005 | 0.45451356156000006
#  *******************************************************************************
#  *                                                                             *
#  *                                 SCALE 6.3.1                                 *
#  *                                -------------                                *
#  *                                   2023-02                                   *
#  *                                                                             *
#  *           SCALE:  A Comprehensive Modeling and Simulation Suite             *
#  *                   for Nuclear Safety Analysis and Design                    *
#  *                                                                             *
#  *                      Reactor and Nuclear Systems Division                   *
#  *                        Oak Ridge National Laboratory                        *
#  *                                                                             *
#  *                           http://scale.ornl.gov                             *
#  *                            scalehelp@ornl.gov                               *
#  *                                                                             *
#  *******************************************************************************
#  *******************************************************************************
#
#                   Job Information
#                   ---------------
#       Job started on ME04L0332LAB04.me.gatech.edu on Sat 2024-12-07 06:15:12
#       Working directory: /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0
#       Input file name  : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat101.inp
#       Output file name : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat101.out
#       SCALE executable : /codes/SCALE-6.3.1/bin/scale
#
#  *******************************************************************************
# mkdir: cannot create directory ‘MonteCarloResults_F33’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘MonteCarloResults_F33/step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# mkdir: cannot create directory ‘tmp_origen_PREDICTOR_step0’: File exists
# cp $INPDIR/../MonteCarloResults_F33/step0/101.f33 mat101.f33
#   Now executing origen
# Scale job /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat101.inp is finished.
# Output is stored in /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat101.out
# Now making standard comp file for material 101  | output= StdCmpMix101_predicted_cmp
#                      NOW RUNNING F71 CONVERSIONS
# STARTING LINE
# ag-109 101 0 2.60941062E-11 900 end
# am-241 101 0 9.35515168E-17 900 end
# am-242 101 0 1.56452783E-19 900 end
# am-242m 101 0 4.14293512E-20 900 end
# am-243 101 0 2.62508519E-19 900 end
# b-10 101 0 6.05722795E-19 900 end
# b-11 101 0 9.70121485E-19 900 end
# ba-140 101 0 5.01263653E-09 900 end
# be-9 101 0 1.93693807E-03 900 end
# c-12 101 0 7.48983257E-02 900 end
# cd-113 101 0 9.92389560E-12 900 end
# ce-141 101 0 4.86270250E-09 900 end
# ce-142 101 0 5.27972016E-09 900 end
# ce-143 101 0 2.00506385E-09 900 end
# ce-144 101 0 5.03908101E-09 900 end
# cm-242 101 0 1.29020483E-19 900 end
# cm-243 101 0 9.91172643E-21 900 end
# cm-244 101 0 1.01927354E-20 900 end
# cs-133 101 0 1.02393626E-09 900 end
# cs-134 101 0 2.99242001E-13 900 end
# cs-135 101 0 1.44912813E-09 900 end
# cs-137 101 0 5.70026912E-09 900 end
# eu-151 101 0 1.03931948E-14 900 end
# eu-153 101 0 7.82639799E-11 900 end
# eu-154 101 0 1.60346951E-13 900 end
# eu-155 101 0 2.86498701E-11 900 end
# eu-156 101 0 1.24139129E-11 900 end
# f-19 101 0 7.74773848E-03 900 end
# gd-152 101 0 4.67931236E-17 900 end
# gd-154 101 0 4.76985225E-17 900 end
# gd-155 101 0 2.65780371E-14 900 end
# gd-156 101 0 1.28163617E-12 900 end
# gd-157 101 0 3.16962370E-12 900 end
# gd-158 101 0 4.72592868E-12 900 end
# gd-160 101 0 3.19864645E-13 900 end
# h-1 101 0 2.74184854E-11 900 end
# i-127 101 0 3.27213138E-11 900 end
# i-129 101 0 3.96645522E-10 900 end
# i-135 101 0 4.58312071E-10 900 end
# in-115 101 0 4.79389592E-12 900 end
# kr-83 101 0 4.65702482E-10 900 end
# la-139 101 0 5.80027574E-09 900 end
# li-6 101 0 2.24122843E-07 900 end
# li-7 101 0 3.87364737E-03 900 end
# mo-100 101 0 5.80653482E-09 900 end
# mo-95 101 0 5.10507050E-12 900 end
# mo-97 101 0 4.34253886E-09 900 end
# mo-98 101 0 5.34018459E-09 900 end
# mo-99 101 0 3.19844427E-09 900 end
# n-14 101 0 1.30633140E-20 900 end
# nb-93 101 0 4.37273113E-18 900 end
# nb-95 101 0 1.52252468E-10 900 end
# nd-143 101 0 3.22281602E-10 900 end
# nd-144 101 0 3.21776185E-11 900 end
# nd-145 101 0 3.36032018E-09 900 end
# nd-146 101 0 2.74349816E-09 900 end
# nd-147 101 0 1.76807440E-09 900 end
# nd-148 101 0 1.54748272E-09 900 end
# np-237 101 0 2.51327818E-12 900 end
# o-16 101 0 2.70205941E-04 900 end
# pd-105 101 0 4.91842023E-10 900 end
# pd-107 101 0 1.42398267E-10 900 end
# pd-108 101 0 5.47294358E-11 900 end
# pm-147 101 0 2.92272120E-10 900 end
# pm-148 101 0 2.33411115E-13 900 end
# pm-149 101 0 4.96894975E-10 900 end
# pr-141 101 0 2.50885641E-10 900 end
# pr-143 101 0 3.15223283E-09 900 end
# pu-238 101 0 1.01043772E-15 900 end
# pu-239 101 0 2.43145818E-08 900 end
# pu-240 101 0 1.21872432E-10 900 end
# pu-241 101 0 6.32914207E-13 900 end
# pu-242 101 0 8.78790737E-16 900 end
# rh-103 101 0 1.17581888E-10 900 end
# rh-105 101 0 3.26068313E-10 900 end
# ru-101 101 0 4.74650035E-09 900 end
# ru-102 101 0 3.96513414E-09 900 end
# ru-103 101 0 2.68891837E-09 900 end
# ru-104 101 0 1.74206754E-09 900 end
# ru-106 101 0 3.79826397E-10 900 end
# sm-147 101 0 3.60710369E-13 900 end
# sm-149 101 0 3.64362029E-10 900 end
# sm-150 101 0 1.15981797E-10 900 end
# sm-151 101 0 2.53069866E-10 900 end
# sm-152 101 0 2.53803761E-10 900 end
# sm-153 101 0 6.86538864E-11 900 end
# sn-126 101 0 5.22451749E-11 900 end
# tc-99 101 0 2.18268549E-09 900 end
# u-234 101 0 5.96759257E-13 900 end
# u-235 101 0 1.71336511E-05 900 end
# u-236 101 0 1.95359329E-08 900 end
# u-238 101 0 1.72111494E-04 900 end
# xe-131 101 0 4.52670091E-10 900 end
# xe-133 101 0 3.51187345E-09 900 end
# xe-135 101 0 1.77814511E-10 900 end
# zr-91 101 0 1.22533242E-10 900 end
# zr-93 101 0 5.11611693E-09 900 end
# zr-94 101 0 5.93681061E-09 900 end
# zr-95 101 0 5.81515238E-09 900 end
# zr-96 101 0 5.84824910E-09 900 end
# ENDING LINE
#  *******************************************************************************
#  *                                                                             *
#  *                                 SCALE 6.3.1                                 *
#  *                                -------------                                *
#  *                                   2023-02                                   *
#  *                                                                             *
#  *           SCALE:  A Comprehensive Modeling and Simulation Suite             *
#  *                   for Nuclear Safety Analysis and Design                    *
#  *                                                                             *
#  *                      Reactor and Nuclear Systems Division                   *
#  *                        Oak Ridge National Laboratory                        *
#  *                                                                             *
#  *                           http://scale.ornl.gov                             *
#  *                            scalehelp@ornl.gov                               *
#  *                                                                             *
#  *******************************************************************************
#  *******************************************************************************
#
#                   Job Information
#                   ---------------
#       Job started on ME04L0332LAB04.me.gatech.edu on Sat 2024-12-07 06:15:18
#       Working directory: /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0
#       Input file name  : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat102.inp
#       Output file name : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat102.out
#       SCALE executable : /codes/SCALE-6.3.1/bin/scale
#
#  *******************************************************************************
#
# cp $INPDIR/../MonteCarloResults_F33/step0/102.f33 mat102.f33
#   Now executing origen
# Scale job /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat102.inp is finished.
# Output is stored in /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat102.out
# Now making standard comp file for material 102  | output= StdCmpMix102_predicted_cmp
#                      NOW RUNNING F71 CONVERSIONS
# STARTING LINE
# ag-109 102 0 3.95829876E-11 900 end
# am-241 102 0 3.70447483E-16 900 end
# am-242 102 0 9.22371173E-19 900 end
# am-242m 102 0 1.99265701E-19 900 end
# am-243 102 0 2.35897086E-18 900 end
# b-10 102 0 8.71871563E-19 900 end
# b-11 102 0 2.03999298E-18 900 end
# ba-140 102 0 7.31365714E-09 900 end
# be-9 102 0 1.93693766E-03 900 end
# c-12 102 0 7.48983245E-02 900 end
# cd-113 102 0 1.31466939E-11 900 end
# ce-141 102 0 7.09449535E-09 900 end
# ce-142 102 0 7.70456596E-09 900 end
# ce-143 102 0 2.92442488E-09 900 end
# ce-144 102 0 7.35093198E-09 900 end
# cm-242 102 0 6.76213585E-19 900 end
# cm-243 102 0 9.92465873E-21 900 end
# cm-244 102 0 1.24578680E-20 900 end
# cs-133 102 0 1.49378399E-09 900 end
# cs-134 102 0 6.75428181E-13 900 end
# cs-135 102 0 1.61947807E-09 900 end
# cs-137 102 0 8.31925881E-09 900 end
# eu-151 102 0 1.48433250E-14 900 end
# eu-153 102 0 1.14352413E-10 900 end
# eu-154 102 0 3.60085256E-13 900 end
# eu-155 102 0 4.10580200E-11 900 end
# eu-156 102 0 1.91232250E-11 900 end
# f-19 102 0 7.74773796E-03 900 end
# gd-152 102 0 9.64475504E-17 900 end
# gd-154 102 0 1.07141495E-16 900 end
# gd-155 102 0 3.70243411E-14 900 end
# gd-156 102 0 1.94787422E-12 900 end
# gd-157 102 0 4.02416069E-12 900 end
# gd-158 102 0 7.64440908E-12 900 end
# gd-160 102 0 4.81732408E-13 900 end
# h-1 102 0 3.50135910E-11 900 end
# i-127 102 0 4.77329382E-11 900 end
# i-129 102 0 5.79724954E-10 900 end
# i-135 102 0 6.68843592E-10 900 end
# in-115 102 0 6.98330305E-12 900 end
# kr-83 102 0 6.78948440E-10 900 end
# la-139 102 0 8.46310793E-09 900 end
# li-6 102 0 2.23305837E-07 900 end
# li-7 102 0 3.87364652E-03 900 end
# mo-100 102 0 8.47472584E-09 900 end
# mo-95 102 0 7.44899778E-12 900 end
# mo-97 102 0 6.33670017E-09 900 end
# mo-98 102 0 7.79321931E-09 900 end
# mo-99 102 0 4.66744944E-09 900 end
# n-14 102 0 1.13311022E-20 900 end
# nb-93 102 0 7.05203489E-18 900 end
# nb-95 102 0 2.22149182E-10 900 end
# nd-143 102 0 4.70022719E-10 900 end
# nd-144 102 0 4.80964198E-11 900 end
# nd-145 102 0 4.90153294E-09 900 end
# nd-146 102 0 4.00393056E-09 900 end
# nd-147 102 0 2.57696189E-09 900 end
# nd-148 102 0 2.26144729E-09 900 end
# np-237 102 0 4.21612643E-12 900 end
# o-16 102 0 2.70206020E-04 900 end
# pd-105 102 0 7.08227734E-10 900 end
# pd-107 102 0 2.12898100E-10 900 end
# pd-108 102 0 8.32673594E-11 900 end
# pm-147 102 0 4.25750362E-10 900 end
# pm-148 102 0 5.38986506E-13 900 end
# pm-149 102 0 7.23327133E-10 900 end
# pr-141 102 0 3.66073986E-10 900 end
# pr-143 102 0 4.59824954E-09 900 end
# pu-238 102 0 2.35726601E-15 900 end
# pu-239 102 0 4.10841845E-08 900 end
# pu-240 102 0 3.04524725E-10 900 end
# pu-241 102 0 2.49693015E-12 900 end
# pu-242 102 0 5.05424095E-15 900 end
# rh-103 102 0 1.71635729E-10 900 end
# rh-105 102 0 4.68423369E-10 900 end
# ru-101 102 0 6.92750336E-09 900 end
# ru-102 102 0 5.79007271E-09 900 end
# ru-103 102 0 3.93030579E-09 900 end
# ru-104 102 0 2.54925939E-09 900 end
# ru-106 102 0 5.60725039E-10 900 end
# sm-147 102 0 5.25548245E-13 900 end
# sm-149 102 0 4.76827145E-10 900 end
# sm-150 102 0 2.25990881E-10 900 end
# sm-151 102 0 3.64417815E-10 900 end
# sm-152 102 0 3.75341562E-10 900 end
# sm-153 102 0 1.00678539E-10 900 end
# sn-126 102 0 7.64265409E-11 900 end
# tc-99 102 0 3.18488142E-09 900 end
# u-234 102 0 7.64072282E-13 900 end
# u-235 102 0 1.70819647E-05 900 end
# u-236 102 0 2.92079336E-08 900 end
# u-238 102 0 1.72075087E-04 900 end
# xe-131 102 0 6.60373288E-10 900 end
# xe-133 102 0 5.12359643E-09 900 end
# xe-135 102 0 1.97147527E-10 900 end
# zr-91 102 0 1.78766283E-10 900 end
# zr-93 102 0 7.46306661E-09 900 end
# zr-94 102 0 8.66032850E-09 900 end
# zr-95 102 0 8.48343039E-09 900 end
# zr-96 102 0 8.53219816E-09 900 end
# ENDING LINE
#  *******************************************************************************
#  *                                                                             *
#  *                                 SCALE 6.3.1                                 *
#  *                                -------------                                *
#  *                                   2023-02                                   *
#  *                                                                             *
#  *           SCALE:  A Comprehensive Modeling and Simulation Suite             *
#  *                   for Nuclear Safety Analysis and Design                    *
#  *                                                                             *
#  *                      Reactor and Nuclear Systems Division                   *
#  *                        Oak Ridge National Laboratory                        *
#  *                                                                             *
#  *                           http://scale.ornl.gov                             *
#  *                            scalehelp@ornl.gov                               *
#  *                                                                             *
#  *******************************************************************************
#  *******************************************************************************
#
#                   Job Information
#                   ---------------
#       Job started on ME04L0332LAB04.me.gatech.edu on Sat 2024-12-07 06:15:24
#       Working directory: /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0
#       Input file name  : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat103.inp
#       Output file name : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat103.out
#       SCALE executable : /codes/SCALE-6.3.1/bin/scale
#
#  *******************************************************************************
#
# cp $INPDIR/../MonteCarloResults_F33/step0/103.f33 mat103.f33
#   Now executing origen
# Scale job /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat103.inp is finished.
# Output is stored in /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat103.out
# Now making standard comp file for material 103  | output= StdCmpMix103_predicted_cmp
#                      NOW RUNNING F71 CONVERSIONS
# STARTING LINE
# ag-109 103 0 5.04403049E-11 900 end
# am-241 103 0 7.22356184E-16 900 end
# am-242 103 0 2.24437216E-18 900 end
# am-242m 103 0 4.70118413E-19 900 end
# am-243 103 0 7.40416042E-18 900 end
# b-10 103 0 1.08034152E-18 900 end
# b-11 103 0 3.16987473E-18 900 end
# ba-140 103 0 9.11719004E-09 900 end
# be-9 103 0 1.93693733E-03 900 end
# c-12 103 0 7.48983234E-02 900 end
# cd-113 103 0 1.51766824E-11 900 end
# ce-141 103 0 8.84344185E-09 900 end
# ce-142 103 0 9.60559638E-09 900 end
# ce-143 103 0 3.64481070E-09 900 end
# ce-144 103 0 9.16274023E-09 900 end
# cm-242 103 0 1.62048109E-18 900 end
# cm-243 103 0 1.00239024E-20 900 end
# cm-244 103 0 1.94523648E-20 900 end
# cs-133 103 0 1.86189933E-09 900 end
# cs-134 103 0 1.04456325E-12 900 end
# cs-135 103 0 1.69964789E-09 900 end
# cs-137 103 0 1.03724241E-08 900 end
# eu-151 103 0 1.81978833E-14 900 end
# eu-153 103 0 1.42621447E-10 900 end
# eu-154 103 0 5.64397904E-13 900 end
# eu-155 103 0 5.06206934E-11 900 end
# eu-156 103 0 2.45932224E-11 900 end
# f-19 103 0 7.74773745E-03 900 end
# gd-152 103 0 1.45521239E-16 900 end
# gd-154 103 0 1.67998440E-16 900 end
# gd-155 103 0 4.45615666E-14 900 end
# gd-156 103 0 2.48715150E-12 900 end
# gd-157 103 0 4.50262325E-12 900 end
# gd-158 103 0 1.01545749E-11 900 end
# gd-160 103 0 6.11715139E-13 900 end
# h-1 103 0 4.35687771E-11 900 end
# i-127 103 0 5.94905233E-11 900 end
# i-129 103 0 7.23437089E-10 900 end
# i-135 103 0 8.33879142E-10 900 end
# in-115 103 0 8.70776803E-12 900 end
# kr-83 103 0 8.45921050E-10 900 end
# la-139 103 0 1.05502300E-08 900 end
# li-6 103 0 2.22676889E-07 900 end
# li-7 103 0 3.87364580E-03 900 end
# mo-100 103 0 1.05665582E-08 900 end
# mo-95 103 0 9.28618292E-12 900 end
# mo-97 103 0 7.89985380E-09 900 end
# mo-98 103 0 9.71624689E-09 900 end
# mo-99 103 0 5.81897168E-09 900 end
# n-14 103 0 1.02828464E-20 900 end
# nb-93 103 0 9.26312317E-18 900 end
# nb-95 103 0 2.76934272E-10 900 end
# nd-143 103 0 5.85717623E-10 900 end
# nd-144 103 0 6.10563303E-11 900 end
# nd-145 103 0 6.10926153E-09 900 end
# nd-146 103 0 4.99209595E-09 900 end
# nd-147 103 0 3.20980459E-09 900 end
# nd-148 103 0 2.82247037E-09 900 end
# np-237 103 0 6.03617853E-12 900 end
# o-16 103 0 2.70206159E-04 900 end
# pd-105 103 0 8.73707864E-10 900 end
# pd-107 103 0 2.69071834E-10 900 end
# pd-108 103 0 1.06248303E-10 900 end
# pm-147 103 0 5.30174880E-10 900 end
# pm-148 103 0 8.12661700E-13 900 end
# pm-149 103 0 9.00062848E-10 900 end
# pr-141 103 0 4.56351911E-10 900 end
# pr-143 103 0 5.73121630E-09 900 end
# pu-238 103 0 4.05046913E-15 900 end
# pu-239 103 0 5.00046329E-08 900 end
# pu-240 103 0 4.65261545E-10 900 end
# pu-241 103 0 4.87271679E-12 900 end
# pu-242 103 0 1.23676216E-14 900 end
# rh-103 103 0 2.14014214E-10 900 end
# rh-105 103 0 5.76424291E-10 900 end
# ru-101 103 0 8.63735797E-09 900 end
# ru-102 103 0 7.22135850E-09 900 end
# ru-103 103 0 4.90458505E-09 900 end
# ru-104 103 0 3.18330900E-09 900 end
# ru-106 103 0 7.03689710E-10 900 end
# sm-147 103 0 6.54525259E-13 900 end
# sm-149 103 0 5.47883513E-10 900 end
# sm-150 103 0 3.30071273E-10 900 end
# sm-151 103 0 4.49503597E-10 900 end
# sm-152 103 0 4.72860577E-10 900 end
# sm-153 103 0 1.25848735E-10 900 end
# sn-126 103 0 9.54597266E-11 900 end
# tc-99 103 0 3.97037394E-09 900 end
# u-234 103 0 9.69440715E-13 900 end
# u-235 103 0 1.70418286E-05 900 end
# u-236 103 0 3.64386289E-08 900 end
# u-238 103 0 1.72055379E-04 900 end
# xe-131 103 0 8.23149112E-10 900 end
# xe-133 103 0 6.38635325E-09 900 end
# xe-135 103 0 2.05997707E-10 900 end
# zr-91 103 0 2.22838648E-10 900 end
# zr-93 103 0 9.30228852E-09 900 end
# zr-94 103 0 1.07947508E-08 900 end
# zr-95 103 0 1.05746163E-08 900 end
# zr-96 103 0 1.06358059E-08 900 end
# ENDING LINE
#  *******************************************************************************
#  *                                                                             *
#  *                                 SCALE 6.3.1                                 *
#  *                                -------------                                *
#  *                                   2023-02                                   *
#  *                                                                             *
#  *           SCALE:  A Comprehensive Modeling and Simulation Suite             *
#  *                   for Nuclear Safety Analysis and Design                    *
#  *                                                                             *
#  *                      Reactor and Nuclear Systems Division                   *
#  *                        Oak Ridge National Laboratory                        *
#  *                                                                             *
#  *                           http://scale.ornl.gov                             *
#  *                            scalehelp@ornl.gov                               *
#  *                                                                             *
#  *******************************************************************************
#  *******************************************************************************
#
#                   Job Information
#                   ---------------
#       Job started on ME04L0332LAB04.me.gatech.edu on Sat 2024-12-07 06:15:30
#       Working directory: /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0
#       Input file name  : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat104.inp
#       Output file name : /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat104.out
#       SCALE executable : /codes/SCALE-6.3.1/bin/scale
#
#  *******************************************************************************
#
# cp $INPDIR/../MonteCarloResults_F33/step0/104.f33 mat104.f33
#   Now executing origen
# Scale job /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat104.inp is finished.
# Output is stored in /home/jfaulkner31/projects/SCALETools/SCALEDepleter/tmp_origen_PREDICTOR_step0/ORIGEN_PREDICTOR_step0_mat104.out
# Now making standard comp file for material 104  | output= StdCmpMix104_predicted_cmp
#                      NOW RUNNING F71 CONVERSIONS
# STARTING LINE
# ag-109 104 0 6.15389889E-11 900 end
# am-241 104 0 1.22718748E-15 900 end
# am-242 104 0 4.56398361E-18 900 end
# am-242m 104 0 9.43432458E-19 900 end
# am-243 104 0 1.72571648E-17 900 end
# b-10 104 0 1.28839731E-18 900 end
# b-11 104 0 4.55910779E-18 900 end
# ba-140 104 0 1.09308664E-08 900 end
# be-9 104 0 1.93693716E-03 900 end
# ...
# 1.461975301447e-10 	|	 0.07097563993950941
# 1.403703397236e-10 	|	 0.06498815016391764
# 1.338067480731e-10 	|	 0.056998300787237256
# 1.247065926853e-10 	|	 0.044439614226855856
# 1.08387308852e-10 	|	 0.03130625889369414
# ================================================
# Substep Number: 2
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 1.565752728279e-10 	|	 0.03854921920135531
# 1.750089513216e-10 	|	 0.04973938116739073
# 1.839954115495e-10 	|	 0.058149420793943064
# 1.90905688903e-10 	|	 0.06263929164492027
# 1.951879827345e-10 	|	 0.06619803075157438
# 1.96220136087e-10 	|	 0.07232375950350702
# 1.959037737371e-10 	|	 0.07651734259992916
# 1.95520342249e-10 	|	 0.07877850077794506
# 1.982447651554e-10 	|	 0.077987236806792
# 2.02536795036e-10 	|	 0.07687052285447094
# 2.049573910604e-10 	|	 0.07349214493566696
# 2.000622265698e-10 	|	 0.06864166105329506
# 1.924678567635e-10 	|	 0.06502831492454354
# 1.857241370402e-10 	|	 0.05811921726407736
# 1.779293899028e-10 	|	 0.044591250506940655
# 1.612983255638e-10 	|	 0.031154705213648805
# ================================================
# Substep Number: 3
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 1.772897886198e-10 	|	 0.03982674937753287
# 1.93515293453e-10 	|	 0.05052388548921108
# 2.010676116538e-10 	|	 0.05864544486122164
# 2.059020390008e-10 	|	 0.06258402199924074
# 2.092713941336e-10 	|	 0.06589601881836964
# 2.105153392384e-10 	|	 0.07208252552871873
# 2.111961238256e-10 	|	 0.0766040365019712
# 2.110526502845e-10 	|	 0.07896695496237324
# 2.127452756267e-10 	|	 0.07783207571250021
# 2.15464833101e-10 	|	 0.07622972422015817
# 2.167689287617e-10 	|	 0.07255939080860162
# 2.130111191757e-10 	|	 0.06800016554967296
# 2.074327429539e-10 	|	 0.06496527899329944
# 2.01941514675e-10 	|	 0.058403368749065654
# 1.93687503133e-10 	|	 0.04458526370120974
# 1.766700436072e-10 	|	 0.031075094726853353
# ================================================
# Substep Number: 4
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 1.86841311989e-10 	|	 0.04039536617429917
# 2.009961549027e-10 	|	 0.050811609920829656
# 2.073092401949e-10 	|	 0.0587897791918747
# 2.103174714332e-10 	|	 0.0625223909802448
# 2.127833715598e-10 	|	 0.0657689495865639
# 2.143856972949e-10 	|	 0.07196268640164032
# 2.160190244314e-10 	|	 0.07657800191476102
# 2.161399211569e-10 	|	 0.07897493158711232
# 2.168237184281e-10 	|	 0.07773064933913344
# 2.177850216082e-10 	|	 0.07604758642267226
# 2.175037400267e-10 	|	 0.07242575915700193
# 2.152012979501e-10 	|	 0.06783082185585752
# 2.118253869027e-10 	|	 0.06489961393402707
# 2.073970188359e-10 	|	 0.05845985838661144
# 1.985726252272e-10 	|	 0.04455203384310671
# 1.808590141819e-10 	|	 0.031029961304263748
# ================================================
# Substep Number: 5
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 1.910552448808e-10 	|	 0.040643386691558835
# 2.040382349131e-10 	|	 0.05092317043460073
# 2.096297453035e-10 	|	 0.05883487545540719
# 2.116861373359e-10 	|	 0.06248986079234313
# 2.137044043148e-10 	|	 0.065717967043629
# 2.155445821665e-10 	|	 0.07191050120868185
# 2.176330829077e-10 	|	 0.0765549703047816
# 2.17917073873e-10 	|	 0.07896425191597539
# 2.180335405358e-10 	|	 0.07768270401885582
# 2.181278420252e-10 	|	 0.07599042282003524
# 2.170889790014e-10 	|	 0.07241410187712331
# 2.155331298847e-10 	|	 0.0677784699258173
# 2.131853435447e-10 	|	 0.06486532025208551
# 2.092112792677e-10 	|	 0.058467559839198116
# 2.0023963331e-10 	|	 0.044532698202629534
# 1.819793255063e-10 	|	 0.031009739217277628
# ================================================
# Substep Number: 6
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 1.930169117222e-10 	|	 0.04075972790762897
# 2.053945741049e-10 	|	 0.05097347414872031
# 2.105766172587e-10 	|	 0.05885268030028451
# 2.121975776267e-10 	|	 0.06247586576667977
# 2.140408908638e-10 	|	 0.06569709875477177
# 2.160366360938e-10 	|	 0.07188829768011454
# 2.182859620198e-10 	|	 0.07654473243930919
# 2.186695085686e-10 	|	 0.07895962134813111
# 2.18482455787e-10 	|	 0.07766251281472974
# 2.182545495051e-10 	|	 0.07596688500469263
# 2.170158597542e-10 	|	 0.07240183754242278
# 2.157397084396e-10 	|	 0.06775341777552266
# 2.1369710995e-10 	|	 0.06485060259344524
# 2.098205955994e-10 	|	 0.05846717262387631
# 2.009704572604e-10 	|	 0.044524539059186435
# 1.822884012842e-10 	|	 0.031001534240484255
# ================================================
# Substep Number: 7
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 1.939903343744e-10 	|	 0.04081840885287336
# 2.061257741606e-10 	|	 0.05100231087314509
# 2.110727680703e-10 	|	 0.058863781651306984
# 2.125074680991e-10 	|	 0.06247050020920063
# 2.142914513328e-10 	|	 0.0656870278292525
# 2.164119955604e-10 	|	 0.0718776585050705
# 2.186941266663e-10 	|	 0.07654250187484435
# 2.191479258549e-10 	|	 0.07896118055482748
# 2.187751232704e-10 	|	 0.07765408093415503
# 2.184337003083e-10 	|	 0.07595216322457049
# 2.171752264978e-10 	|	 0.07238364699751125
# 2.160323965926e-10 	|	 0.06773452319490554
# 2.140129598228e-10 	|	 0.0648449275660956
# 2.100643491901e-10 	|	 0.05846703510683014
# 2.014653966916e-10 	|	 0.0445219968586511
# 1.824143884874e-10 	|	 0.03099825576676023
# ================================================
# Substep Number: 8
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 1.945460066231e-10 	|	 0.0408525722806917
# 2.06638021056e-10 	|	 0.05102398022893212
# 2.114374684653e-10 	|	 0.058873831115872494
# 2.127933439281e-10 	|	 0.0624686798156595
# 2.145612043972e-10 	|	 0.06568044756783345
# 2.168003139226e-10 	|	 0.07187102552289025
# 2.190665551658e-10 	|	 0.07654422683837699
# 2.195794402745e-10 	|	 0.0789663863738466
# 2.190661455087e-10 	|	 0.07765012211737864
# 2.186740726764e-10 	|	 0.07593927149672101
# 2.174265118815e-10 	|	 0.07236313631456248
# 2.163958144773e-10 	|	 0.06771653096358017
# 2.143087701496e-10 	|	 0.06484294833282017
# 2.102136459726e-10 	|	 0.058468140042228896
# 2.01921277726e-10 	|	 0.044521879420157257
# 1.825150960339e-10 	|	 0.030996821568448473
# ================================================
# Substep Number: 9
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 1.949272033575e-10 	|	 0.04087643911605577
# 2.07082135153e-10 	|	 0.051043660078395475
# 2.117763835464e-10 	|	 0.05888434128052936
# 2.130957698642e-10 	|	 0.06246830576708738
# 2.148627676192e-10 	|	 0.065674874505556
# 2.17223425096e-10 	|	 0.07186567119947498
# 2.194571289049e-10 	|	 0.0765479101639393
# 2.20025934962e-10 	|	 0.07897366397472284
# 2.193866488858e-10 	|	 0.07764782071289135
# 2.189574651541e-10 	|	 0.07592631250481945
# 2.177200409514e-10 	|	 0.0723412820242171
# 2.168060836823e-10 	|	 0.06769808646543211
# 2.146244164627e-10 	|	 0.06484246993262913
# 2.10350545219e-10 	|	 0.05847028878096759
# 2.023867520512e-10 	|	 0.04452280235488638
# 1.826229526406e-10 	|	 0.030996071138396038
# ================================================
# Substep Number: 10
# MatID - Xenon BOSubstep | Power BOSubstep
# Last Xenon entry is the EOS of the last substep - this no assoicated power vector.
# 101 - 1.952396136908e-10 		|		 N\A
# 102 - 2.075125678792e-10 		|		 N\A
# 103 - 2.121220956371e-10 		|		 N\A
# 104 - 2.134200170905e-10 		|		 N\A
# 105 - 2.151916621523e-10 		|		 N\A
# 106 - 2.176798871331e-10 		|		 N\A
# 107 - 2.198759642127e-10 		|		 N\A
# 108 - 2.205006395533e-10 		|		 N\A
# 109 - 2.197381203962e-10 		|		 N\A
# 110 - 2.192708357817e-10 		|		 N\A
# 111 - 2.180418159538e-10 		|		 N\A
# 112 - 2.172499520339e-10 		|		 N\A
# 113 - 2.149648304865e-10 		|		 N\A
# 114 - 2.104971145566e-10 		|		 N\A
# 115 - 2.028708144821e-10 		|		 N\A
# 116 - 1.827412034449e-10 		|		 N\A
# ================================================
# Xenon Concentration by step num - BOSubstep concentrations
# 101 1e-20 1.03337012879e-10 1.565752728279e-10 1.772897886198e-10 1.86841311989e-10 1.910552448808e-10 1.930169117222e-10 1.939903343744e-10 1.945460066231e-10 1.949272033575e-10 1.952396136908e-10
# 102 1e-20 1.225176631824e-10 1.750089513216e-10 1.93515293453e-10 2.009961549027e-10 2.040382349131e-10 2.053945741049e-10 2.061257741606e-10 2.06638021056e-10 2.07082135153e-10 2.075125678792e-10
# 103 1e-20 1.321907669938e-10 1.839954115495e-10 2.010676116538e-10 2.073092401949e-10 2.096297453035e-10 2.105766172587e-10 2.110727680703e-10 2.114374684653e-10 2.117763835464e-10 2.121220956371e-10
# 104 1e-20 1.388002456942e-10 1.90905688903e-10 2.059020390008e-10 2.103174714332e-10 2.116861373359e-10 2.121975776267e-10 2.125074680991e-10 2.127933439281e-10 2.130957698642e-10 2.134200170905e-10
# 105 1e-20 1.425625525247e-10 1.951879827345e-10 2.092713941336e-10 2.127833715598e-10 2.137044043148e-10 2.140408908638e-10 2.142914513328e-10 2.145612043972e-10 2.148627676192e-10 2.151916621523e-10
# 106 1e-20 1.442837535107e-10 1.96220136087e-10 2.105153392384e-10 2.143856972949e-10 2.155445821665e-10 2.160366360938e-10 2.164119955604e-10 2.168003139226e-10 2.17223425096e-10 2.176798871331e-10
# 107 1e-20 1.44748430402e-10 1.959037737371e-10 2.111961238256e-10 2.160190244314e-10 2.176330829077e-10 2.182859620198e-10 2.186941266663e-10 2.190665551658e-10 2.194571289049e-10 2.198759642127e-10
# 108 1e-20 1.448093956899e-10 1.95520342249e-10 2.110526502845e-10 2.161399211569e-10 2.17917073873e-10 2.186695085686e-10 2.191479258549e-10 2.195794402745e-10 2.20025934962e-10 2.205006395533e-10
# 109 1e-20 1.4661052112e-10 1.982447651554e-10 2.127452756267e-10 2.168237184281e-10 2.180335405358e-10 2.18482455787e-10 2.187751232704e-10 2.190661455087e-10 2.193866488858e-10 2.197381203962e-10
# 110 1e-20 1.491660264476e-10 2.02536795036e-10 2.15464833101e-10 2.177850216082e-10 2.181278420252e-10 2.182545495051e-10 2.184337003083e-10 2.186740726764e-10 2.189574651541e-10 2.192708357817e-10
# 111 1e-20 1.500221554531e-10 2.049573910604e-10 2.167689287617e-10 2.175037400267e-10 2.170889790014e-10 2.170158597542e-10 2.171752264978e-10 2.174265118815e-10 2.177200409514e-10 2.180418159538e-10
# 112 1e-20 1.461975301447e-10 2.000622265698e-10 2.130111191757e-10 2.152012979501e-10 2.155331298847e-10 2.157397084396e-10 2.160323965926e-10 2.163958144773e-10 2.168060836823e-10 2.172499520339e-10
# 113 1e-20 1.403703397236e-10 1.924678567635e-10 2.074327429539e-10 2.118253869027e-10 2.131853435447e-10 2.1369710995e-10 2.140129598228e-10 2.143087701496e-10 2.146244164627e-10 2.149648304865e-10
# 114 1e-20 1.338067480731e-10 1.857241370402e-10 2.01941514675e-10 2.073970188359e-10 2.092112792677e-10 2.098205955994e-10 2.100643491901e-10 2.102136459726e-10 2.10350545219e-10 2.104971145566e-10
# 115 1e-20 1.247065926853e-10 1.779293899028e-10 1.93687503133e-10 1.985726252272e-10 2.0023963331e-10 2.009704572604e-10 2.014653966916e-10 2.01921277726e-10 2.023867520512e-10 2.028708144821e-10
# 116 1e-20 1.08387308852e-10 1.612983255638e-10 1.766700436072e-10 1.808590141819e-10 1.819793255063e-10 1.822884012842e-10 1.824143884874e-10 1.825150960339e-10 1.826229526406e-10 1.827412034449e-10
# ================================================
# Power by step num - BOS value - constant from BOSubstep to EOSubstep
# 101 0.0284400000000000030.035155397485619970.038549219201355310.039826749377532870.040395366174299170.0406433866915588350.040759727907628970.040818408852873360.04085257228069170.04087643911605577
# 102 0.041610.047356314998726750.049739381167390730.050523885489211080.0508116099208296560.050923170434600730.050973474148720310.051002310873145090.051023980228932120.051043660078395475
# 103 0.0518700000000000060.05644538531737920.0581494207939430640.058645444861221640.05878977919187470.058834875455407190.058852680300284510.0588637816513069840.0588738311158724940.05888434128052936
# 104 0.0621750000000000150.06258180820252980.062639291644920270.062584021999240740.06252239098024480.062489860792343130.062475865766679770.062470500209200630.06246867981565950.06246830576708738
# 105 0.069050000000000010.067040352196089980.066198030751574380.065896018818369640.06576894958656390.0657179670436290.065697098754771770.06568702782925250.065680447567833450.065674874505556
# 106 0.074190.072897278779153850.072323759503507020.072082525528718730.071962686401640320.071910501208681850.071888297680114540.07187765850507050.071871025522890250.07186567119947498
# 107 0.073970000000000020.075935380692985850.076517342599929160.07660403650197120.076578001914761020.07655497030478160.076544732439309190.076542501874844350.076544226838376990.0765479101639393
# 108 0.074950000000000020.077870870351418260.078778500777945060.078966954962373240.078974931587112320.078964251915975390.078959621348131110.078961180554827480.07896638637384660.07897366397472284
# 109 0.078555000000000010.078220291856987450.0779872368067920.077832075712500210.077730649339133440.077682704018855820.077662512814729740.077654080934155030.077650122117378640.07764782071289135
# 110 0.085175000000000010.079144166399133350.076870522854470940.076229724220158170.076047586422672260.075990422820035240.075966885004692630.075952163224570490.075939271496721010.07592631250481945
# 111 0.087855000000000020.07742478970876150.073492144935666960.072559390808601620.072425759157001930.072414101877123310.072401837542422780.072383646997511250.072363136314562480.0723412820242171
# 112 0.077025000000000010.070975639939509410.068641661053295060.068000165549672960.067830821855857520.06777846992581730.067753417775522660.067734523194905540.067716530963580170.06769808646543211
# 113 0.0646150.064988150163917640.065028314924543540.064965278993299440.064899613934027070.064865320252085510.064850602593445240.06484492756609560.064842948332820170.06484246993262913
# 114 0.0538800000000000040.0569983007872372560.058119217264077360.0584033687490656540.058459858386611440.0584675598391981160.058467172623876310.058467035106830140.0584681400422288960.05847028878096759
# 115 0.0439150.0444396142268558560.0445912505069406550.044585263701209740.044552033843106710.0445326982026295340.0445245390591864350.04452199685865110.0445218794201572570.04452280235488638
# 116 0.0315050000000000050.031306258893694140.0311547052136488050.0310750947268533530.0310299613042637480.0310097392172776280.0310015342404842550.030998255766760230.0309968215684484730.030996071138396038
# ================================================
# Predictor Xenon at T1 | Xenon from Corrector at T1 | Predictor Power from Transport | Corrected power in last substep
# 101 - 1.77814511e-10 1.952396136908e-10 0.03987480062599687 0.04087643911605577
# 102 - 1.97147527e-10 2.075125678792e-10 0.05070474647626762 0.051043660078395475
# 103 - 2.05997707e-10 2.121220956371e-10 0.058824705876470616 0.05888434128052936
# 104 - 2.11418158e-10 2.134200170905e-10 0.06260468697656513 0.06246830576708738
# 105 - 2.14872521e-10 2.151916621523e-10 0.06581967090164549 0.065674874505556
# 106 - 2.15761288e-10 2.176798871331e-10 0.07203963980180099 0.07186567119947498
# 107 - 2.16606091e-10 2.198759642127e-10 0.07668461657691711 0.0765479101639393
# 108 - 2.1648448e-10 2.205006395533e-10 0.07908460457697711 0.07897366397472284
# 109 - 2.18276968e-10 2.197381203962e-10 0.0778246108769456 0.07764782071289135
# 110 - 2.20918256e-10 2.192708357817e-10 0.07600961995190023 0.07592631250481945
# 111 - 2.21470133e-10 2.180418159538e-10 0.07222963885180574 0.0723412820242171
# 112 - 2.18095302e-10 2.172499520339e-10 0.06778966105169475 0.06769808646543211
# 113 - 2.12979779e-10 2.149648304865e-10 0.06498467507662462 0.06484246993262913
# 114 - 2.07507141e-10 2.104971145566e-10 0.05853970730146349 0.05847028878096759
# 115 - 1.98697097e-10 2.028708144821e-10 0.044609776951115246 0.04452280235488638
# 116 - 1.8269767e-10 1.827412034449e-10 0.03106484467577662 0.030996071138396038
#
#
# ================================================================
