# %%
import numpy as np
import scaleParsing
import pandas as pd

# %%
lines = scaleParsing.open_message_file('delete_me.msg')
powers = scaleParsing.get_mixture_powers(lines)
pd.DataFrame.from_dict(data=powers).to_csv('delete_me.csv')

# %%
# Out:
# {161: array([ 7272500.,  7616300.,  7590400.,  7719000.,  7853700.,  8014600.,
#          8335600.,  8575100.,  8879600.,  9446800.,  9645000., 10712000.,
#         10302000., 11306000., 11149000., 11866000., 11812000., 11934000.,
#         12503000., 12258000., 12783000., 12711000., 13266000., 13266000.]),
#  162: array([ 9921500., 10246000., 10168000., 10321000., 10479000., 10633000.,
#         10947000., 11154000., 11447000., 11987000., 12070000., 13161000.,
#         12536000., 13571000., 13266000., 13959000., 13847000., 13842000.,
#         14405000., 14075000., 14616000., 14443000., 14932000., 14932000.]),
#  163: array([12785000., 13014000., 12926000., 13063000., 13158000., 13260000.,
#         13503000., 13562000., 13770000., 14114000., 13945000., 14862000.,
#         14067000., 14931000., 14466000., 15001000., 14765000., 14626000.,
#         15089000., 14658000., 15029000., 14769000., 15072000., 15072000.]),
# ...
